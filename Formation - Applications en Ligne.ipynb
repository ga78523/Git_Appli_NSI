# %% [markdown]
# <img src="img/titre.jpg">

# %% [markdown]
# <div style="font-size: 1.3em;">
# <u><b>Contenu</b></u> :<br><br>
# </div>
# <a href="#-I.-Exemples-d'applications-en-ligne-:-" > I. Exemples d'applications en ligne : </a><br />
# <a href="#-II.-Pourquoi-travailler-avec-un-Jupyter-Notebook-:-Ce-que-fait-Voila-:-" > II. Pourquoi travailler avec un Jupyter Notebook : Ce que fait Voila : </a><br />
# <a href="#-III.-Téléchargement-/-installation-:-" > III. Téléchargement / installation : </a><br />
# <ul>
#     <li><a href="#-III.a-Téléchargement-/installation-d'Anaconda-(Python++)-:-" > III.a Téléchargement /installation d'Anaconda (Python++) : </a><br /></li>
#     <li><a href="#-III.b-Téléchargement-/installation-de-Jupyter-Notebook-:-" > III.b Téléchargement /installation de Jupyter Notebook : </a><br /></li>
#     <li><a href="#-III.c-Téléchargement-/installation-de-Voila-:-" > III.c Téléchargement /installation de Voila : </a><br /></li>
# </ul>
# <a href="#-IV.-Environnement-et-Requirements.txt-:-" > IV. Environnement et Requirements.txt : </a><br />
# <a href="#-V.-Créations-de-comptes-:-préalabe-au-déploiement-de-l'appli-:-" > V. Créations de comptes : préalabe au déploiement de l'appli : </a><br />
# <ul>
#     <li><a href="#-V.a-Création-d'une-nouvelle-adresse-Gmail-(facultatif)-:-" > V.a Création d'une nouvelle adresse Gmail (facultatif) : </a><br /></li>
#     <li><a href="#-V.b-Création-d'un-compte-Github-:-" > V.b Création d'un compte Github : </a><br /></li>
#     <li><a href="#-V.c-Création-d'un-compte-Heroku-(à-titre-informel..)-:-" > V.c Création d'un compte Heroku (à titre informel..) : </a><br /></li>
#     <li><a href="#-V.d-Création-d'un-compte-Render-:-" > V.d Création d'un compte Render : </a><br /></li>
# </ul>
# <a href="#-VI.-Déploiement-de-l'appli-:-" > VI. Déploiement de l'appli : </a><br />
# <ul>
#     <li><a href="#-VI.a-Création-d'un-dépôt-(Repo-==-Repository)-Github-:-" > VI.a Création d'un dépôt (Repo == Repository) Github : </a><br /></li>
#         <li><a href="#-VI.b-Déploiement-de-l'appli-sur-Render.com-:-" > VI.b Déploiement de l'appli sur Render.com : </a><br /></li>
#     <ul>
#         <li><a href="#-VI.b.1-Paramétrage-de-l'appli-:-" > VI.b.1 Paramétrage de l'appli : </a><br /></li>
#         <li><a href="#-VI.b.2-Adaptation-du-requirements.txt-au-deploiement-sur-Render-:-" > VI.b.2 Adaptation du requirements.txt au deploiement sur Render : </a><br /></li>
#     </ul>

# %% [markdown]
# <div style="border:2px solid green;margin:0px 10px 10px 10px;padding:10px;">
# <u><h2> I. Exemples d'applications en ligne : </h2></u>
#
# <a href="" target="_blank">Appli de dénombrement bactérien</a>
#
# <a href="" target="_blank">Applis_NSI</a>

# %% [markdown]
# <div style="border:2px solid blue;margin:0px 10px 10px 10px;padding:10px;">
# <u><h2> II. Pourquoi travailler avec un Jupyter Notebook : Ce que fait Voila : </h2></u><br>
#     Lorsqu'on utilise un <b>éditeur de code</b> en <b>Python</b> : IDLE ( Integrated DeveLopment Environment )<br>
# <ul>
#     Cela génère des fenêtres de travail (interfaces graphiques générées par PyQt, TKinter..)<br>
#     <ul>
#         <li><u>Spyder</u> : </li>
#         <img src="img/spyder.jpg">
#         <li><u>Visual Studio Code</u> :</li>
#         <img src="img/MS_VS.jpg">
#     </ul>
# <br>
# Lorsque vous ouvrez un <b><span style="color:chocolate">Jupyter Notebook</span></b>, la fenêtre qui s'ouvre est un <b><u>navigateur</u></b> :
# <img src="img/Notebook.jpg">
#     Dès lors, nous avons du <b>code Python qui s'exprime dans un navigateur</b><br>
#     <ul>
#         <u>On s'est donc rapproché de notre but</u> : <span style="color:DodgerBlue">Créer une application en Python qui s'exprime sur le Web, c'est à dire via un navigateur</span>...<br>
#         <br><ul><i><u>Problème </u> : le Jupyter Notebook dans le navigateur nous présente le code...</i></ul><br><br>
# <u>Solution</u> : <a href="Matrice_demo_voila.ipynb" target="_blank">Ce que fait Voila</a>

# %% [markdown]
# <u><h2> III. Téléchargement / installation : </h2></u>

# %% [markdown]
# <div style="text-align:center; border:0px ;background-color:FireBrick;margin:10px 10px 0px 10px;padding:10px;">
#     </div>
# <div style="border:2px solid red;margin:0px 10px 10px 10px;padding:10px;">
# <img src="img/anaconda_.png" width="50px" align="left"/>
# <br><u><h2> III.a Téléchargement /installation d'Anaconda (Python++) : </h2></u>
#     <b><i><span style="color:green">Vous permet d'avoir Python, et surtout <u>Jupyter Notebook</u>.</span></i></b>
# <br><br><u>Vous rendre à cette URL</u> :
#
# https://www.anaconda.com/products/distribution#Downloads

# %% [markdown]
# <div style="text-align:center; border:0px ;background-color:FireBrick;margin:10px 10px 0px 10px;padding:10px;">
#     </div>
# <div style="border:2px solid red;margin:0px 10px 10px 10px;padding:10px;">
# <img src="img/jupyter notebook.png" width="50px" align="left"/>
# <br><u><h2> III.b Téléchargement /installation de Jupyter Notebook : </h2></u>
#     <b><i><span style="color:chocolate">Indispensable pour réaliser des Applis en ligne en Python</u>.</span></i></b>
# <br><br><u>Ouvrir une invite de commande (cmd)</u> :
# <ul>
#     <li>On va d'abord tester si 'pip' est à jour dans notre système :</li><br>
#     <ul>
#         <b>pip3 install --upgrade pip</b><br>
#         <i>( ou : anaconda3\python.exe -m pip install --upgrade pip )</i>
#     </ul><br>
#     <li>puis on va pouvoir installer le jupyter notebook :</li><br>
#     <ul>
#         <b>pip3 install jupyter</b>
#     </ul>
# <br>
# <i><u>Voici un lien vers la doc complète</u> :</i>
#
# https://docs.jupyter.org/en/latest/install/notebook-classic.html

# %% [markdown]
# <div style="text-align:center; border:0px ;background-color:FireBrick;margin:10px 10px 0px 10px;padding:10px;">
#     </div>
# <div style="border:2px solid red;margin:0px 10px 10px 10px;padding:10px;">
# <img src="img/voila_.png" width="50px" align="left"/>
# <br><u><h2> III.c Téléchargement /installation de Voila : </h2></u>
# <b><i><span style="color:DarkCyan">Indispensable pour éliminer le code du visuel de l'Appli</u>.</span></i></b>
# <br><br><u>Ouvrir une invite de commande (cmd) et entrer</u> :
# <ul>
#     <b>pip3 install voila
#     <br><br>voila --enable_nbextensions=True
#     <br><br>jupyter notebook --VoilaConfiguration.enable_nbextensions=True</b></ul>
# <i><u>Voici un lien vers la doc complète</u> :</i>
#
# https://voila.readthedocs.io/en/stable/

# %% [markdown]
# <u><h2> IV. Environnement et Requirements.txt : </h2></u><br>
# <b><i><ul>--> Lancez le Powerpoint.</ul></i></b>

# %%
# ! POWERPNT.EXE /S C:\Users\dfial\OneDrive\0000_Moi_Formateur_NSI_Appli_Web\Présentation_Form-Appli_Web.pptx

# %% [markdown]
# <div style="border:2px solid blue;margin:0px 10px 10px 10px;padding:10px;">
# * Allez à cette URL :
#
# <a href="https://github.com/dfialaire/Formation_Appli_NSI_Fialaire_2022" target="_blank">github.com/dfialaire/Formation_Appli_NSI_Fialaire_2022</a>
#
# * Cliquez sur le bouton vert <button type="button" style="background-color:#4CAF50; color:white;">Code</button>
# * Cliquez sur :<br> <img align="left" src="img/zip.png"><br><br>
# * Récupérez l'archive .zip (dans vos téléchargements) et dézippez-là <u><b>dans</b></u> un dossier que vous pourrez nommer '<i><b> Formation_Appli </b></i>'<br><br>
# * Ouvrez un prompt (ligne de commande : cmd) et faites en sorte d'être localisé dans le dossier '<i><b> Formation_Appli </b></i>'<br>
# <i><span style="color:green">( Une fois le dossier ouvert, dans la barre d'adresse, écrivez cmd et faîtes entrée. )</span></i>
# * <u>Dans le prompt</u>:
# <ul>
#     <li>On va d'abord tester si 'pip' est à jour dans notre système :</li><br>
#     <ul>
#         Ecrivez : <b><span style="color:purple">pip3 install --upgrade pip</span></b><br>
#         <i>( ou : <span style="color:purple">anaconda3\python.exe -m pip install --upgrade pip</span> )</i>
#     </ul><br>
#     <li>Ecrivez : <b><span style="color:purple">pip freeze</span></b></li>
#     <ul> --> Vous obtenez la liste de tous les modules Python qui sont enregistrés sur <b><u>votre</u></b> machine, ainsi que leur version.<br><br></ul>
# </ul>
# * Nous allons à présent <b><u>construire un environnement</u></b> vierge dans lequel vous pourrez sereinement participer à cette formation :
# <ol>
#     <li>Cela protège votre ordinateur des actions que nous allons mener ;</li>
#     <li>Cela va nous apporter des informations essentielles (modules et dépendances) pour la construction de l'appli.</li>
# </ol>
# <br>
# * <u>Dans le prompt</u>:
# <ul>
#         Ecrivez :
#     <ul>
#     <b><span style="color:purple">pip3 install virtualenv</span></b><br>
#     <b><span style="color:purple">virtualenv Form_Appli</span></b><br>
#     <b><span style="color:purple">pip freeze</span></b><br>
# <ul>--> On observe les mêmes modules.. L'environnement n'est pas encore actif !</ul>
# <b><span style="color:purple">.\Form_Appli\Scripts\activate</span></b><br>
# <ul>--> On observe en ligne de commande : <b><span style="color:green">(Form_Appli)</span></b> D:\PartC\000_Formation_NSI_App_en_ligne\Formation_Appli></ul>
# <b><span style="color:purple">python.exe -m pip install --upgrade pip</span></b><br>
# <b><span style="color:purple">pip freeze</span></b><br>
# <ul>Le freeze ne renvois aucun module : <b><i>C'est normal</i></b>, on est dans l'environnement 'vierge'.<ul>Donc, normalement, on ne devrait pas avoir accès au module Jupyter notebook...?
#
#     </ul>
#
# Ecrivez :<ul><b><span style="color:purple">jupyter notebook</span></b> <br>
# <ul><span style="color:red">Normalement le Notebook n'aurait pas dû s'ouvrir puisque nous n'avons pas installé Jupyter Notebook dans notre environnement...</span>
# <ul>--> Cliquez sur le notebook ' <b>Appli_NSI.ipynb </b>'..
#     <ul>.. Le notebook s'ouvre ; Exécutez la 1ère cellule d'import de modules..
#         <ul>==> <i><span style="color:red">elle s'exécute normalement !? (si vous possédez déjà tous les modules sur votre environnement de base)</span></i><br><br>
#         <i>C'est parce que le 'noyau' Jupyter qui s'active démarre<br>
#         obligatoirement depuis l'extérieur de l'environnement..</i><br><br>
#         <b><span style="color:green">* Copiez l'ensemble des lignes de la 1ère cellule de ce notebook.</span></b><br><br>
#         <b><span style="color:green">* Collez ces lignes dans un éditeur python (Notepad++, spyder) et enregistrez sous : "imports.py" dans votre dossier 'Formation_Appli'.</span></b><br><br></ul>
#         <li>Revenez au notebook ouvert, cliquez, en haut à droite, sur 'Logout'</li>
#         <li>revenez dans le prompt, et réalisez un : <b><span style="color:blue">Ctrl c"</span></b> pour revenir<br>
#         au <u>prompt de notre environnement activé</u>.</li>
#
#     </ul>
#
# <li>Faîtes un <b><span style="color:purple">dir</span></b> pour vérifier que votre fichier <b><span style="color:green">imports.py</span></b> est bien présent.</li><br>
# <ul><ul>Ecrivez :
# <ul><b><span style="color:purple">python imports.py</span></b><br><br>
# python nous renvois :<br>
#     <ul>
#         Traceback (most recent call last):<br>
#   File "imports.py", line 1, in module<br>
#         <b>import <i><span style="color:blue">ipywidgets</span></i></b><br>
# ModuleNotFoundError: No module named 'ipywidgets'<br>
#         <ul>
#             <b><span style="color:green">C'est normal</span></b>
#         </ul>
#
# <b><span style="color:purple">pip3 install ipywidgets==7.6.3</span></b><br><br>
#     <ul>
#         <b><span style="color:green">... Successfully installed Send2Trash-1.8.0 anyio-3.6.2 argon2-cffi-21.3.0 argon2-cffi-bindings-21.2.0 asttokens-2.1.0 attrs-22.1.0 backcall-0.2.0 beautifulsoup4-4.11.1 bleach-5.0.1 cffi-1.15.1 colorama-0.4.6 debugpy-1.6.3 decorator-5.1.1 defusedxml-0.7.1 entrypoints-0.4 executing-1.2.0 fastjsonschema-2.16.2 idna-3.4 importlib-metadata-5.0.0 ipykernel-6.17.1 ipython-8.6.0 ipython-genutils-0.2.0 ipywidgets-7.6.3 jedi-0.18.1 jinja2-3.1.2 jsonschema-4.17.0 jupyter-client-7.4.6 jupyter-core-5.0.0 jupyter-server-1.23.2 jupyterlab-pygments-0.2.2 jupyterlab-widgets-3.0.3 markupsafe-2.1.1 matplotlib-inline-0.1.6 mistune-2.0.4 nbclassic-0.4.8 nbclient-0.7.0 nbconvert-7.2.5 nbformat-5.7.0 nest-asyncio-1.5.6 notebook-6.5.2 notebook-shim-0.2.2 packaging-21.3 pandocfilters-1.5.0 parso-0.8.3 pickleshare-0.7.5 platformdirs-2.5.4 prometheus-client-0.15.0 prompt-toolkit-3.0.32 psutil-5.9.4 pure-eval-0.2.2 pycparser-2.21 pygments-2.13.0 pyparsing-3.0.9 pyrsistent-0.19.2 python-dateutil-2.8.2 pywin32-305 pywinpty-2.0.9 pyzmq-24.0.1 six-1.16.0 sniffio-1.3.0 soupsieve-2.3.2.post1 stack-data-0.6.1 terminado-0.17.0 tinycss2-1.2.1 tornado-6.2 traitlets-5.5.0 wcwidth-0.2.5 webencodings-0.5.1 websocket-client-1.4.2 widgetsnbextension-3.5.2 zipp-3.10.0</span></b><br><br>
#     </ul>
#         <b><span style="color:purple">python imports.py</span></b><br><br>
#     python nous renvois :<br>
#     <ul>Traceback (most recent call last):
#   File "imports.py", line 2, in module<br>
#    <b> from <i><span style="color:blue">ipywebrtc</span></i> import CameraStream, ImageRecorder</b><br>
# ModuleNotFoundError: No module named 'ipywebrtc'<br>
# <ul>
#     <b><span style="color:green">C'est normal</span></b>
#         </ul>
# <b><span style="color:purple">pip3 install ipywebrtc==0.6.0</span></b><br><br>
#         <ul>
#         <b><span style="color:green">... Successfully installed ipywebrtc-0.6.0</span></b><br><br>
#     </ul>
#         <b><span style="color:purple">python imports.py</span></b><br><br>
#     python nous renvois :<br>
# <ul>
#     <li>Traceback (most recent call last):<br>
#   File "imports.py", line 8, in module<br>
#         import <b><i><span style="color:blue">cv2</span></i></b><br>
# ModuleNotFoundError: No module named <b><i><span style="color:blue">cv2</span></i></b><br><br>
#         <b><span style="color:purple">pip3 install opencv-python-headless</span></b><br>
# <u>voir</u> :<br>
#
# <a href="https://pypi.org/project/opencv-python-headless/" target="_blank">( Packages for server (headless) )</a>
#
# <ul>
#         <b><span style="color:green">... Successfully installed numpy-1.23.4 opencv-python-headless-4.6.0.66</span></b><br><br>
#     </ul>
#         <b><span style="color:purple">python imports.py</span></b><br><br>
#     python nous renvois :<br>
#     <ul>Traceback (most recent call last):
#   File "imports.py", line 11, in module<br>
#    <b> import <i><span style="color:blue">PIL.Image</span></i></b><br>
# ModuleNotFoundError: No module named 'PIL'<br>
# <ul>
#             <b><span style="color:green">C'est normal</span></b>
#         </ul>
# <b><span style="color:purple">pip3 install Pillow</span></b><br><br>
#         <ul>
#         <b><span style="color:green">... Successfully installed Pillow-9.2.0</span></b><br><br>
#     </ul>
#         <b><span style="color:purple">python imports.py</span></b><br><br>
#
# python nous renvois : <b><span style="color:green">Rien !</span></b><br>
# <br>

# %% [markdown]
# <div style="border:2px solid Coral;margin:0px 10px 10px 10px;padding:10px;">N'oublions pas d'ajouter dans cet environnement :
# <ul>
#         <li>voila : <b><span style="color:purple">pip3 install voila==0.3.6</span></b></li>
#     </ul>
# <b><span style="color:green">...Successfully installed babel-2.11.0 certifi-2022.9.24 charset-normalizer-2.1.1 json5-0.9.10 jupyterlab-server-2.16.3 lxml-4.9.1 mistune-0.8.4 nbclient-0.5.13 nbconvert-6.5.4 pytz-2022.6 requests-2.28.1 urllib3-1.26.12 voila-0.3.6 websockets-10.4</span></b>
# <br><br>
#     A présent, nous allons pouvoir construire un fichier '<b><i> requirements.txt '</i></b> qui contiendra les noms de tous les modules et dépendances nécessaires à notre appli :</li>
#     <ul>
#         <b><span style="color:purple">pip3 freeze > requirements.txt</span></b>
#         <br>
#         --> ouvrez le fichier, vous verrez qu'il est conséquent, mais bien plus court que le pip freeze de votre machine sans votre environnement.

# %% [markdown]
# <u><h2> V. Créations de comptes : préalabe au déploiement de l'appli : </h2></u><br>

# %% [markdown]
# <div style="text-align:center; border:0px ;background-color:FireBrick;margin:10px 10px 0px 10px;padding:10px;">
#     </div>
# <div style="border:2px solid red;margin:0px 10px 10px 10px;padding:10px;">
# <img src="img/gmail.png" width="50px" align="left"/>
# <br><u><h2> V.a Création d'une nouvelle adresse Gmail (facultatif) : </h2></u>
#     <b><i><span style="color:blue">Vous permet</span><span style="color:red"> de gérer efficacement</span><span style="color:orange"> les autorisations pour </span><span style="color:green"><u>Github</u> et <u>render</u>.</span></i></b>
# <br><br><u>Pour créer une nouvelle adresse Gmail, se rendre à l'adresse</u> :
#
# https://accounts.google.com/signup/v2/webcreateaccount?flowName=GlifWebSignIn&flowEntry=SignUp

# %% [markdown]
# <div style="text-align:center; border:0px ;background-color:FireBrick;margin:10px 10px 0px 10px;padding:10px;">
#     </div>
# <div style="border:2px solid red;margin:0px 10px 10px 10px;padding:10px;">
# <img src="img/github.png" width="50px" align="left"/>
# <br><u><h2> V.b Création d'un compte Github : </h2></u>
# <b><i><span style="color:DimGray">Permet le stockage des fichiers (public/privé) : indispensable pour construire l'Appli</u>.</span></i></b>
# <br><br>Vous rendre à :<br>
#
# https://github.com/
#
# <ul>
#     <li>Cliquez sur : Sign up</li>
#     <li>Entrez une adresse mail (Attention : 1 compte Github / adresse mail !)</li>
#     <li>Définissez un mot de passe</li>
#     <li>Définissez un nom usuel</li>
#     <li>Validez le test : je ne suis pas un robot.</li>
#     <li>Cliquez sur Créez l'accompte</li>
#     <li>Vérifiez/Récupérez dans votre boîte mail le code d'accès..</li>
#     <li>Remplissez le formulaire</li>
# </ul>
# <ul>
#         <li>Cliquez sur : Continue for free</li>
# </ul>
# <b><span style = "color: green">ça y est, vous avez un compte Github !</span></b>

# %% [markdown]
# <div style="text-align:center; border:0px ;background-color:FireBrick;margin:10px 10px 0px 10px;padding:10px;">
#     </div>
# <div style="border:2px solid red;margin:0px 10px 10px 10px;padding:10px;">
# <img src="img/heroku.png" width="75px" align="left"/>
# <br><u><h2> V.c Création d'un compte Heroku (à titre informel..) : </h2></u>
# <b><i><span style="color:Indigo ">Plateforme de déploiement en ligne d'applications (devenue payante le 28/11/22 !).</span></i></b>
# <br><br>Vous rendre à : <br>
#
# https://www.heroku.com/
# <ul>
#     <li>Cliquez sur les barres de menu</li>
#     <li>Cliquez sur : Sign up</li>
#     <li>Remplissez le formulaire en mettant :</li>
#     <ul>
#             <li>L'adresse mail utilisée pour le compte Github</li>
#             <li>En choisissant : Python : comme 1er language de développement</li>
#     </ul>
#     <li>Cliquez sur : I'm not a robot, puis sur : Create free account</li>
#     <ul>
#         <li>Vérifiez votre boite mail pour cliquer sur le lien heroku validant le compte</li>
#         <li>Définissez un mot de passe et validez pour vous identifier</li>
#         <li>Validez les 'termes of service' en cliquant sur Accept.</li>
#     </ul>
#     <li>Cliquez sur le menu (3x3 points) : et sélectionnez : Dashbord (tableau de bord)</li>
#
# <b><span style = "color: green">ça y est, vous avez un compte Heroku ! (<i>payant</i>)</span></b>

# %% [markdown]
# <div style="text-align:center; border:0px ;background-color:FireBrick;margin:10px 10px 0px 10px;padding:10px;">
#     </div>
# <div style="border:2px solid red;margin:0px 10px 10px 10px;padding:10px;">
# <img src="img/render.jpg" width="50px" align="left"/>
# <br><u><h2> V.d Création d'un compte Render : </h2></u>
# <b><i><span style="color:LightSeaGreen ">Plateforme de déploiement en ligne d'applications .</span></i></b>
# <br><br>Vous rendre à : <br>
#
# https://www.render.com/
# <ul>
#     <li>Cliquez, en haut à droite, sur GET STARTED,</li>
#     </ul>
#     <i>Pour simplifier l'accès au compte Render, et aux depôts Github, nous allons<br>
#         nous créer un compte via Github..</i>
#     <ul>
#         <li>Cliquez sur Github</li>
#         <ul>
#             <li>Inscrivez l'adresse mail qui vous a servi à créer un compte Github,
#             <li>Renseignez le mot de passe de votre compte Github..</li>
#             <li>et cliquez sur <b>Sign in</b></li>
# <br>
#             <li>Vous recevez alors un mail de demande de confirmation de <b>Github</b>..</li>
#             <ul>
#                 <li>Dedans se trouve un nombre à 6 chiffres.. inscrivez ce nombre dans le formulaire qui apparait.</li>
#             </ul>
#             <i><u>Ps</u> : Vous recevez alors un mail de Github pour vous signaler cette inter-connexion</i>
#             <ul>
#                 <li>Cliquez alors sur le bouton vert <span style="color:green"><b>Autorize Render</b></span></li>
#                 <li>Cliquez ensuite sur le bouton bleu <span style="color:blue"><b>COMPLETE SIGN UP</b></span></li>
#             </ul>
# <br>
#             <li>Ensuite, vous devez ouvrir votre boite mail, pour lire le mail envoyé par <b>Render</b>, et cliquer sur le lien qui vous permettra de finaliser l'activation de votre compte Render.</li>
#
# <b><span style = "color: green">ça y est, vous avez un compte Render ! (gratuit)</span>

# %% [markdown]
# <u><h2> VI. Déploiement de l'appli : </h2></u><br>

# %% [markdown]
# <div style="text-align:center; border:0px ;background-color:FireBrick;margin:10px 10px 0px 10px;padding:10px;">
#     </div>
# <div style="border:2px solid red;margin:0px 10px 10px 10px;padding:10px;">
# <img src="img/github.png" width="50px" align="left"/>
# <br><u><h2> VI.a Création d'un dépôt (Repo == Repository) Github : </h2></u>
#
# <br>Allez sur votre compte Github :<br>
#
# https://github.com/
#
# <ul>
#     <li>Cliquez sur le bouton vert <button type="button" style="background-color:#4CAF50; color:white;">New</button>, ou, en haut à droite, sur le + --> New repository</li>
#     <li>Donnez un nom à votre nouveau repository : <b>Git_Appli_NSI</b></li>
#     <li>Vous pouvez donner une description si vous le souhaitez..</li>
#     <li>Restez en Public,</li>
#     <li>N'oubliez pas de cocher : Add a read me file (=page de présentation de votre Repo)</li>
#     <li>Enfin, cliquez sur <button type="button" style="background-color:#4CAF50; color:white;">Create a repository</button></li>
# </ul>
# Votre repository <b>Git_Appli_NSI</b> s'ouvre : il ne contient qu'un README.
# <ul>
#         <li>Cliquez sur le bouton <button type="button" style="background-color:#ebedf0; color:black;">Add file</button> --> Upload files</li>
#     <li>Cliquez sur <u><span style="color:blue">choose your files</span></u></li>
#     <ul>
#         <li>Déplacez vous dans l'exploreur de fichiers de Github pour atteindre le dossier '<b>Formation_Appli</b>'</li>
#         <ul>
#             <li>Sélectionnez tous les fichiers suivants :</li>
#             <ul><span style="color:green">
#                 <li>Appli_NSI.ipynb</li>
#                 <li>Lycee_NSI.jpg</li>
#                 <li>requirements.txt</li></span>
#             </ul>
#         </ul>
#     </ul>
# </ul>
#     Enfin, très <span style="color:red"><b><u>important</u></b></span> : il vous faut <u>valider</u> la transformation de votre Repo = " commiter " !
# <ul>
#     <b>==></b> cliquez sur <button type="button" style="background-color:#4CAF50; color:white;">Commit changes</button>
#     </ul>

# %% [markdown]
# <div style="text-align:center; border:0px ;background-color:FireBrick;margin:10px 10px 0px 10px;padding:10px;">
#     </div>
# <div style="border:2px solid red;margin:0px 10px 10px 10px;padding:10px;">
# <img src="img/render.jpg" width="50px" align="left"/>
# <br><u><h2> VI.b Déploiement de l'appli sur Render.com : </h2></u>
# <br>Allez sur votre compte Render.com : <br>
#
# https://www.render.com/
#
# <ul>
# <i><u><h3> VI.b.1 Paramétrage de l'appli : </h3></u></i><br>
# <li>Dans votre <b><span style="color:blue">Dashbord</span></b>, cliquez sur le bouton <button type="button" style="color:white; background-image: linear-gradient(90deg, rgb(111, 137, 251) 0%, rgb(92, 110, 245) 29%, rgb(81, 81, 236) 100%);">New +</button>,</li>
#     <ul>
#         <li>..et choisissez <button type="button" style="color:white; background-image: linear-gradient(90deg, rgb(111, 137, 251) 0%, rgb(92, 110, 245) 29%, rgb(81, 81, 236) 100%);">Web Service</button></li>
#         <li>Render vous demande de choisir dans la liste de tous vos repository (à partir du + récent) celui qui sera le support de votre appli :</li>
#         <ul>
#             <li>Sélectionnez <b>Git_Appli_NSI</b> en cliquant sur son bouton <button type="button" style="color:white; background-image: linear-gradient(90deg, rgb(111, 137, 251) 0%, rgb(92, 110, 245) 29%, rgb(81, 81, 236) 100%);">Connect</button></li>
#             <ol>
#                 <li>Donnez un <b><span style="color:blue">Name</span></b> à votre appli : ex : <b>Appli_NSI_Formation_VOTRENOM</b></li>
#                 <li>Laissez <b><span style="color:blue">Environnement</span></b> à <b>Python3</b></li>
#                 <li>Au niveau de la <b><span style="color:blue">Region</span></b>, sélectionnez <b>Frankfurt</b> (Europe)</li>
#                 <li>Au niveau du <b><span style="color:blue">Build Command</span></b>, laissez <b>pip install -r requirements.txt</b></li><br>
# <li>Au niveau du <b><span style="color:blue">Start Command</span></b>, <u>écrire</u> : <b>voila --port=$PORT --no-browser --Voila.ip=0.0.0.0  Appli_NSI.ipynb</b></li><br>
# <li>Laissez le <b><span style="color:blue">Plan Type</span></b> à <b>Free</b>, et descendez..</li>
# <li>Cliquez sur le bouton <button type="button" style="background-color:white; color:blue;">Advanced</button>
# <ul>
# <li>Modifiez l'<b><span style="color:blue">Auto Deploy</span></b> à <b>No</b></li>
# </ul>
# <li>Enfin, cliquez sur le bouton <button type="button" style="color:white; background-image: linear-gradient(90deg, rgb(111, 137, 251) 0%, rgb(92, 110, 245) 29%, rgb(81, 81, 236) 100%);">Create Web Service</button></li>
# <ul>
# Le déploiement débute : il vous indique l'heure, le nom du repository et le N° du dernier commit..
# </ul>
#             </ol>
#         </ul></ul>
# </ul>

# %% [markdown]
# <div style="text-align:center; border:0px ;background-color:FireBrick;margin:10px 10px 0px 10px;padding:10px;">
#     </div>
# <div style="border:2px solid red;margin:0px 10px 10px 10px;padding:10px;">
# <img src="img/render.jpg" width="50px" align="left"/>
# <ul>
#     <i><u><h3> VI.b.2 Adaptation du requirements.txt au deploiement sur Render : </h3></u></i><br>
#     <li> ...Il commence le déploiement, il collecte les modules et dépendances, puis signale une erreur.
# <img src="img/error6.jpg"><br>
#     On demande <b><span style="color:red">ipykernel==6.17.1</span></b>, et cette version n'existe pas sur le serveur..<br>
#     il nous présente toutes les versions qu'il possède<br>
#         <b><i><span style="color:blue">Nous n'allons <b>pas choisir la version la plus récente</b>, mais plutôt la version qui fonctionne bien : </span></i> <span style="color:green">6.15.3</span></b>
#     <ul>
#         Ouvrez votre repository, cliquez sur le fichier 'requirements.txt', cliquez sur le crayon ; Modifiez la version du module <b>ipykernel</b>.. et n'oubliez pas de faire un <button type="button" style="background-color:#4CAF50; color:white;">Commit changes</button><br>
#         Revenir sur Render et cliquez alors sur le bouton <button type="button" style="color:white; background-image: linear-gradient(90deg, rgb(111, 137, 251) 0%, rgb(92, 110, 245) 29%, rgb(81, 81, 236) 100%);">Manual Deploy</button>, <br>
#         <ul>
#             puis sur <button type="button" style="background-color:white; color:blue;">Clear build cache & deploy</button>
#         </ul>
#     </ul>
#     </ul><br>
# <ul>
#     <li> ...Il <b>recommence</b> le déploiement, il collecte les modules et dépendances, puis signale une <b>nouvelle</b> erreur.
# <img src="img/error1.jpg"><br>
#     On demande <b><span style="color:red">ipython==8.5.0</span></b>, et cette version n'existe pas sur le serveur..<br>
#     il nous présente toutes les versions qu'il possède<br>
#     <b><i><span style="color:blue">Nous allons choisir la version la plus récente : </span></i> <span style="color:green">7.34.0</span></b>
#     <ul>
#         Ouvrez votre repository, cliquez sur le fichier 'requirements.txt', cliquez sur le crayon ; Modifiez la version du module <b>ipython</b>.. et n'oubliez pas de faire un <button type="button" style="background-color:#4CAF50; color:white;">Commit changes</button><br>
#         Revenir sur Render et cliquez alors sur le bouton <button type="button" style="color:white; background-image: linear-gradient(90deg, rgb(111, 137, 251) 0%, rgb(92, 110, 245) 29%, rgb(81, 81, 236) 100%);">Manual Deploy</button>, <br>
#         <ul>
#             puis sur <button type="button" style="background-color:white; color:blue;">Clear build cache & deploy</button>
#         </ul>
#     </ul>
#     </ul><br>
#
#     <ul>
#     <li> ...Il <b>recommence</b> le déploiement, il collecte les modules et dépendances, puis signale une <b>nouvelle</b> erreur.
# <img src="img/error7.jpg"><br>
#     On demande <b><span style="color:red">jupyter_core==5.0.0</span></b>, et cette version n'existe pas sur le serveur..<br>
#     il nous présente toutes les versions qu'il possède<br>
#     <b><i><span style="color:blue">Nous allons choisir la version : </span></i> <span style="color:green">4.11.1</span></b>
#     <ul>
#         <u>Problème</u> : si on change la version de Jupyter-core, il serait aussi prudent de changer les versions de tous les autres modules Jupyter ;<br>
#         Ouvrez votre repository, cliquez sur le fichier 'requirements.txt', cliquez sur le crayon ; Modifiez la version des modules <b>Jupyter</b> suivant :<br><br>
# jupyter-core==4.11.1<br>
# jupyter-server==1.18.1<br>
# jupyter_client==7.3.5<br>
# jupyterlab-pygments==0.2.2<br>
# jupyterlab-widgets==3.0.3<br>
# jupyterlab_server==2.15.1<br>
# .. et n'oubliez pas de faire un <button type="button" style="background-color:#4CAF50; color:white;">Commit changes</button><br>
#         Revenir sur Render et cliquez alors sur le bouton <button type="button" style="color:white; background-image: linear-gradient(90deg, rgb(111, 137, 251) 0%, rgb(92, 110, 245) 29%, rgb(81, 81, 236) 100%);">Manual Deploy</button>, <br>
#         <ul>
#             puis sur <button type="button" style="background-color:white; color:blue;">Clear build cache & deploy</button>
#         </ul>
#     </ul>
#     </ul><br>
#
# <ul>
#     <li> ...Il <b>recommence</b> le déploiement, il collecte les modules et dépendances, puis signale une <b>nouvelle</b> erreur.
# <img src="img/error2.jpg"><br>
#     On demande <b><span style="color:red">numpy==1.23.4</span></b>, et cette version n'existe pas sur le serveur..<br>
#     il nous présente toutes les versions qu'il possède<br>
#     <b><i><span style="color:blue">Nous allons choisir la version la plus récente : </span></i> <span style="color:green">1.21.6</span></b>
#     <ul>
#         Ouvrez votre repository, cliquez sur le fichier 'requirements.txt', cliquez sur le crayon ; Modifiez la version du module <b>numpy</b>.. et n'oubliez pas de faire un <button type="button" style="background-color:#4CAF50; color:white;">Commit changes</button><br>
#         Revenir sur Render et cliquez alors sur le bouton <button type="button" style="color:white; background-image: linear-gradient(90deg, rgb(111, 137, 251) 0%, rgb(92, 110, 245) 29%, rgb(81, 81, 236) 100%);">Manual Deploy</button>, <br>
#         <ul>
#             puis sur <button type="button" style="background-color:white; color:blue;">Clear build cache & deploy</button>
#         </ul>
#     </ul>
#     </ul><br>
# <ul>
#     <li> ...Il <b>recommence</b> le déploiement, il collecte les modules et dépendances, puis signale une <b>nouvelle</b> erreur.
# <img src="img/error3.jpg"><br>
#     On demande <b><span style="color:red">pywin32==304</span></b>, et cette version n'existe pas sur le serveur..<br>
#         <b><span style="color:red">D'ailleurs, il n'en possède <u>aucune</u> version !</span></b> En effet, le module pywin permet de gérer les accès à des API Windows...<br>
#         <b><span style="color:green">Nous allons donc éliminer les 2 modules pywin</span></b> de notre requirements.
#     <ul>
#         Ouvrez votre repository, cliquez sur le fichier 'requirements.txt', cliquez sur le crayon ; retirez les 2 modules  <b>pywin</b>.. et n'oubliez pas de faire un <button type="button" style="background-color:#4CAF50; color:white;">Commit changes</button><br>
#         Revenir sur Render et cliquez alors sur le bouton <button type="button" style="color:white; background-image: linear-gradient(90deg, rgb(111, 137, 251) 0%, rgb(92, 110, 245) 29%, rgb(81, 81, 236) 100%);">Manual Deploy</button>, <br>
#         <ul>
#             puis sur <button type="button" style="background-color:white; color:blue;">Clear build cache & deploy</button>
#         </ul>
#     </ul>
#         </ul><br>
# <ul>
#     <li> ...Il <b>recommence</b> le déploiement, il collecte les modules et dépendances, <b><i>et finalement, il annonce que le déploiement est réussi !!</i></b>
# <img src="img/deploy1.jpg"><br>
#     <li>Remontez sur la page Render ; En haut à gauche, vous avez l'URL de votre appli : </li>
#     </ul>
# https://xxxxxxx.onrender.com ; copiez l'URL et lancez là dans un nouvel onglet :
# <img src="Img/App.jpg">

# %% [markdown]
# ## A vous de jouer :
#
# https://ipywidgets.readthedocs.io/en/stable/examples/Widget%20List.html
